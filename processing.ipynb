# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('seattle-weather.csv')

# %%
data
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather
# 0     2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1     2012-01-02           10.9      10.6       2.8   4.5     rain
# 2     2012-01-03            0.8      11.7       7.2   2.3     rain
# 3     2012-01-04           20.3      12.2       5.6   4.7     rain
# 4     2012-01-05            1.3       8.9       2.8   6.1     rain
# ...          ...            ...       ...       ...   ...      ...
# 1456  2015-12-27            8.6       4.4       1.7   2.9     rain
# 1457  2015-12-28            1.5       5.0       1.7   1.3     rain
# 1458  2015-12-29            0.0       7.2       0.6   2.6      fog
# 1459  2015-12-30            0.0       5.6      -1.0   3.4      sun
# 1460  2015-12-31            0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 6 columns]

# %%
data.head()
# Out:
#          date  precipitation  temp_max  temp_min  wind  weather
# 0  2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1  2012-01-02           10.9      10.6       2.8   4.5     rain
# 2  2012-01-03            0.8      11.7       7.2   2.3     rain
# 3  2012-01-04           20.3      12.2       5.6   4.7     rain
# 4  2012-01-05            1.3       8.9       2.8   6.1     rain

# %%
data.isnull().sum()
# Out:
# date             0
# precipitation    0
# temp_max         0
# temp_min         0
# wind             0
# weather          0
# dtype: int64

# %%
df=pd.DataFrame(data)

# %%
df.head()
# Out:
#          date  precipitation  temp_max  temp_min  wind  weather
# 0  2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1  2012-01-02           10.9      10.6       2.8   4.5     rain
# 2  2012-01-03            0.8      11.7       7.2   2.3     rain
# 3  2012-01-04           20.3      12.2       5.6   4.7     rain
# 4  2012-01-05            1.3       8.9       2.8   6.1     rain

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           1461 non-null   str
#  1   precipitation  1461 non-null   float64
#  2   temp_max       1461 non-null   float64
#  3   temp_min       1461 non-null   float64
#  4   wind           1461 non-null   float64
#  5   weather        1461 non-null   str
# dtypes: float64(4), str(2)
# memory usage: 68.6 KB

# %%
df.describe(include="all")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df.describe(include=True)
#
# File c:\Users\asadu\miniconda3\envs\myenv\Lib\site-packages\pandas\core\generic.py:11426, in NDFrame.describe(self, percentiles, include, exclude)
#   11180 @final
#   11181 def describe(
#   11182     self,
#    (...)  11185     exclude=None,
#   11186 ) -> Self:
#   11187     """
#   11188     Generate descriptive statistics.
#   11189
#    (...)  11424     max            NaN      3.0
#   11425     """
# > 11426     return describe_ndframe(
#   11427         obj=self,
#   11428         include=include,
#   11429         exclude=exclude,
#   11430         percentiles=percentiles,
#   11431     ).__finalize__(self, method="describe")
#
# File c:\Users\asadu\miniconda3\envs\myenv\Lib\site-packages\pandas\core\methods\describe.py:97, in describe_ndframe(obj, include, exclude, percentiles)
#      90 else:
#      91     describer = DataFrameDescriber(
#      92         obj=cast("DataFrame", obj),
#      93         include=include,
#      94         exclude=exclude,
#      95     )
# ---> 97 result = describer.describe(percentiles=percentiles)
#      98 return cast(NDFrameT, result)
#
# File c:\Users\asadu\miniconda3\envs\myenv\Lib\site-packages\pandas\core\methods\describe.py:167, in DataFrameDescriber.describe(self, percentiles)
#     166 def describe(self, percentiles: Sequence[float] | np.ndarray) -> DataFrame:
# --> 167     data = self._select_data()
#     169     ldesc: list[Series] = []
#     170     for _, series in data.items():
#
# File c:\Users\asadu\miniconda3\envs\myenv\Lib\site-packages\pandas\core\methods\describe.py:198, in DataFrameDescriber._select_data(self)
#     196     data = self.obj
#     197 else:
# --> 198     data = self.obj.select_dtypes(
#     199         include=self.include,
#     200         exclude=self.exclude,
#     201     )
#     202     if len(data.columns) == 0:
#     203         msg = "No columns match the specified include or exclude data types"
#
# File c:\Users\asadu\miniconda3\envs\myenv\Lib\site-packages\pandas\core\frame.py:5491, in DataFrame.select_dtypes(self, include, exclude)
#    5488             converted_dtypes.append(infer_dtype_from_object(dtype))
#    5489     return frozenset(converted_dtypes)
# -> 5491 include = check_int_infer_dtype(include)
#    5492 exclude = check_int_infer_dtype(exclude)
#    5494 for dtypes in (include, exclude):
#
# File c:\Users\asadu\miniconda3\envs\myenv\Lib\site-packages\pandas\core\frame.py:5488, in DataFrame.select_dtypes.<locals>.check_int_infer_dtype(dtypes)
#    5486         converted_dtypes.extend([np.float64, np.float32])
#    5487     else:
# -> 5488         converted_dtypes.append(infer_dtype_from_object(dtype))
#    5489 return frozenset(converted_dtypes)
#
# File c:\Users\asadu\miniconda3\envs\myenv\Lib\site-packages\pandas\core\dtypes\common.py:1767, in infer_dtype_from_object(dtype)
#    1758     except (AttributeError, TypeError):
#    1759         # Handles cases like _get_dtype(int) i.e.,
#    1760         # Python objects that are valid dtypes
#    (...)   1763         # TypeError handles the float16 type code of 'e'
#    1764         # further handle internal types
#    1765         pass
# -> 1767 return infer_dtype_from_object(np.dtype(dtype))
#
# TypeError: Cannot interpret 'True' as a data type
