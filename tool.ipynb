# %%
res=lambda x:x**2
print(res(5))
# Out:
# 25

# %%
print("--------Lambda Function is here-------")
res=lambda x:x**2
print(res(5))
print(res(4))
print(res(2))
res=lambda y :y**3
print(res(2))
lst=[1,2,3,4,6,8]
result=list(filter(lambda x:x%2==0,lst))
print(result)
# Out:
# --------Lambda Function is here-------
# 25
# 16
# 4
# 8
# [2, 4, 6, 8]

# %%
data = [[1, 5], [2, 3], [4, 1]]
sorted_data = sorted(data, key=lambda x: x[1])
print(sorted_data)
# Out:
# [[4, 1], [2, 3], [1, 5]]

# %%
words = ["apple", "kiwi", "banana"]
sorted_words=sorted(words,key=lambda x:len(x))
print(sorted_words)
# Out:
# ['kiwi', 'apple', 'banana']

# %%
nums = [10, 3, 45, 7]
res=max(nums, key=lambda x: x)
print(res)
# Out:
# 45

# %%
def multiplier(n):
    return lambda x: x * n
double = multiplier(2)
print(double(5))
# Out:
# 10

# %%
x = lambda a: lambda b: a * b
print(x(2)(3))
# Out:
# 6

# %%
nums = [1, 2, 3, 4]
res=map(lambda x:x**2,nums)
print(list(res))
# Out:
# [1, 4, 9, 16]

# %%
words = ["hello", "world"]
res=map(lambda x:x.upper(),words)
print(list(res))
# Out:
# ['HELLO', 'WORLD']

# %%
nums = [1, 2, 3]
res=map(lambda x:str(x),nums)
print(list(res))
# Out:
# ['1', '2', '3']

# %%
nums = [1, 2, 3]
res=map(lambda x:x+10,nums)
print(list(res))
# Out:
# [11, 12, 13]

# %%
a = [1, 2, 3]
b = [4, 5, 6]
# output → [5, 7, 9]
res=map(lambda x,y:x+y,a,b)
print(list(res))
# Out:
# [5, 7, 9]

# %%
words = ["apple", "banana", "cherry"]
res=map(lambda x:x[0],words)
print(list(res))
# Out:
# ['a', 'b', 'c']

# %%
nums = [1, 2, 3]
result = map(lambda x: x * 2, nums)
print(list(result))
# Out:
# [2, 4, 6]

# %%
nums = [1, 2, 3, 4, 5]
result = filter(lambda x: x % 2 == 0, nums)
print(list(result))
# Out:
# [2, 4]

# %%
nums = [-2, -1, 0, 1, 2]
result = filter(lambda x: x > 0, nums)
print(list(result))
# Out:
# [1, 2]

# %%
words = ["cat", "elephant", "dog", "tiger"]
res=filter(lambda x:len(x)>4,words)
print(list(res))
# Out:
# ['elephant', 'tiger']

# %%
nums = [3, 5, 9, 10, 12]
res=filter(lambda x:x%3==0,nums)
print(list(res))
# Out:
# [3, 9, 12]

# %%
data = ["hello", "", "world", "", "python"]
res=filter(lambda x: x != "", data)
print(list(res))
# Out:
# ['hello', 'world', 'python']

# %%
words = ["madam", "hello", "level"]
res=filter(lambda x: x == x[::-1], words)
print(list(res))
# Out:
# ['madam', 'level']

# %%
RES=list(filter(None, [0, 1, "", "hello", False, True]))
print(RES)
# Out:
# [1, 'hello', True]

# %%
from functools import reduce
nums = [10, 5, 20, 8]
red=reduce(lambda x,y: max(x, y), nums)
print(red)
# Out:
# 20

# %%
def add_numbers(*args):
    print(args)

add_numbers(1, 2, 3)
# Out:
# (1, 2, 3)

# %%
def demo(a, b, *args, **kwargs):
    print(a, b)
    print(args)
    print(kwargs)

demo(1, 2, 3, 4, 5, x=10, y=20)
# Out:
# 1 2
# (3, 4, 5)
# {'x': 10, 'y': 20}

# %%
# Out:
# (1, 2, 3)

# %%
def show(**kwrgs):
    print(kwrgs)
show(name="Alice", age=30, city="New York")
# Out:
# {'name': 'Alice', 'age': 30, 'city': 'New York'}

# %%
def show(*args):
    max_num=max(args)
    return max_num
print(show(1, 5, 3, 9, 2))
# Out:
# 9

# %%
def combine(*args):
    return ''.join(str(arg) for arg in args)
array=[[1,2],[3,4]]
print(combine(*array))
# Out:
# [1, 2][3, 4]

# %%
def greet(**kwrgs):
    print(f"Hello, {kwrgs.get('name','Guest')}!")
greet(name="Asadullah")
# Out:
# Hello, Asadullah!

# %%
def tricky(a, *args, **kwargs):
    print(a)
    print(args)
    print(kwargs)
tricky(10, 20, 30, x=40, y=50)
# Out:
# 10
# (20, 30)
# {'x': 40, 'y': 50}

# %%
def add(a, b, c):
    return a + b + c

nums = (1, 2, 3)

print(add(*nums))
# Out:
# 6

# %%
def merge_dicts(**kwargs):
    return kwargs
print(merge_dicts(a=1, b=2, c=3))
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
def student_record(*args, **kwargs):
    print("ID: ",args)
    print("Details :",kwargs)
student_record(101, 102, name="Ali", age=20)
# Out:
# ID:  (101, 102)
# Details : {'name': 'Ali', 'age': 20}

# %%
try:
    num=int(input("Enter a number here"))
    print(f"You entered: {num}")
except ValueError:
    print("invalid input, please enter a valid number")
finally:
    print("This block always executes")
# Out:
# invalid input, please enter a valid number
# This block always executes

# %%
try:
    num=int(input("Enter a number:........"))
    division=10/num
    print(f"Result of division: {float(division)}")
except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")
finally:
    print("This block always executes.")
# Out:
# Error: Division by zero is not allowed.
# This block always executes.

# %%
def show(**kwrgs):
    try:
        name,age=kwrgs['name'],kwrgs['age']
        print(f"Hello, {name}! You are {age} years old.")
    except KeyError:
        print(f"Error: Missing required key")
    finally:
        print("This block always executes.")
show(name="Asad", age=25)
print('------------------------------')
show(age=23)
# Out:
# Hello, Asad! You are 25 years old.
# This block always executes.
# ------------------------------
# Error: Missing required key
# This block always executes.

# %%
class AgeValidationError(Exception):
    pass

age=25
try:    
    if age < 18:
        raise AgeValidationError("Age must be at least 18.")
    else:
        print("Age is valid.")
except AgeValidationError as e:
    print(f"Validation Error: {e}")
finally:
    print("This block always executes.")
