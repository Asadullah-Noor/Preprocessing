# %%
d="this is is a test this is"
words=d.split()
print(words)
# Out:
# ['this', 'is', 'is', 'a', 'test', 'this', 'is']

# %%
repeated_words={word for word in words if words.count(word)}
print({word: words.count(word) for word in repeated_words})
# Out:
# {'test': 1, 'this': 2, 'a': 1, 'is': 3}

# %%
Input: dict[str, int] = {"a": 3, "is": 3, "this": 2}
integar = {key: value for key, value in Input.items() if value > 2}
print(integar)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 2
#       1 Input: dict[str, int] = {"a": 3, "is": 3, "this": 2}
# ----> 2 integar={integar: value for value in Input.dict.Int if value > 2}
#       3 print(integar)
#
# AttributeError: 'dict' object has no attribute 'dict'
